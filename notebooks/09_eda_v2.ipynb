# %% [markdown]
# ## 讀取資料

# %%
import pandas as pd

# %%
df_dataset = pd.read_csv(r'D:\Python\我的AI作品集\專案1_數學函數辨識\data\v2\function_dataset_v2.csv')

# %%
print(f"數據外型: {df_dataset.shape}")
# Out:
# 數據外型: (4000, 13)

# %%
print(f"前5筆資料:\n{df_dataset.head()}")
# Out:
# 前5筆資料:
#    sample_id   label       y_0       y_1       y_2       y_3       y_4  \
# 0          0  linear -2.686173 -2.557886 -1.990353 -1.325905 -0.893967
# 1          1  linear -3.124748 -2.634489 -1.945079 -1.429697 -0.864389
# 2          2  linear -4.293363 -4.343122 -4.416289 -4.476034 -4.536854
# 3          3  linear -2.074955 -1.644308 -1.433193 -1.063882 -0.770663
# 4          4  linear -0.682675 -0.189459  0.301764  0.852574  1.560830
#
#         y_5       y_6       y_7       y_8       y_9  noise_sigma
# 0 -0.369784  0.013501  0.715469  1.189897  1.588625     0.124065
# 1 -0.321805  0.371766  0.858915  1.415485  1.994077     0.062923
# 2 -4.588158 -4.644501 -4.710495 -4.773649 -4.832726     0.005496
# 3 -0.461110 -0.110195  0.143041  0.479129  0.735107     0.075105
# 4  1.806619  2.522043  2.735324  3.396324  3.962124     0.111954

# %%
print(f"欄位:\n{df_dataset.columns.tolist()}")
# Out:
# 欄位:
# ['sample_id', 'label', 'y_0', 'y_1', 'y_2', 'y_3', 'y_4', 'y_5', 'y_6', 'y_7', 'y_8', 'y_9', 'noise_sigma']

# %%
print(f"資料型態:\n{df_dataset.dtypes}")
# Out:
# 資料型態:
# sample_id        int64
# label              str
# y_0            float64
# y_1            float64
# y_2            float64
# y_3            float64
# y_4            float64
# y_5            float64
# y_6            float64
# y_7            float64
# y_8            float64
# y_9            float64
# noise_sigma    float64
# dtype: object

# %%
print(f"缺失值:\n{df_dataset.isnull().sum()}\n")
# Out:
# 缺失值:
# sample_id      0
# label          0
# y_0            0
# y_1            0
# y_2            0
# y_3            0
# y_4            0
# y_5            0
# y_6            0
# y_7            0
# y_8            0
# y_9            0
# noise_sigma    0
# dtype: int64

# %%
print(f"各函數類型數量:\n{df_dataset['label'].value_counts()}\n")       # 查看各類別數量
# Out:
# 各函數類型數量:
# label
# linear         500
# quadratic      500
# cubic          500
# exponential    500
# logarithmic    500
# sine           500
# cosine         500
# reciprocal     500
# Name: count, dtype: int64

# %%
print(f"各函數類型比例:\n{df_dataset['label'].value_counts(normalize=True)}\n") # 查看比例
# Out:
# 各函數類型比例:
# label
# linear         0.125
# quadratic      0.125
# cubic          0.125
# exponential    0.125
# logarithmic    0.125
# sine           0.125
# cosine         0.125
# reciprocal     0.125
# Name: proportion, dtype: float64

# %%
print(f"Noise 統計:\n{df_dataset['noise_sigma'].describe()}")           # 查看noise分布
# Out:
# Noise 統計:
# count    4000.000000
# mean        0.090622
# std         0.118544
# min         0.001000
# 25%         0.018330
# 50%         0.046722
# 75%         0.111325
# max         0.920102
# Name: noise_sigma, dtype: float64

# %%
df_metadata = pd.read_csv(r'D:\Python\我的AI作品集\專案1_數學函數辨識\data\v2\function_metadata_v2.csv')

# %%
# 查看基本資料資訊
print(f"數據外型: {df_metadata.shape}")
# Out:
# 數據外型: (4000, 7)

# %%
print(f"前5筆資料:\n{df_metadata.head()}\n")
# Out:
# 前5筆資料:
#    sample_id   label   param_1   param_2  param_3  param_4  noise_sigma
# 0          0  linear  1.095824 -0.611216      NaN      NaN     0.124065
# 1          1  linear  1.291046 -0.565858      NaN      NaN     0.062923
# 2          2  linear -0.133116 -4.561962      NaN      NaN     0.005496
# 3          3  linear  0.679256 -0.628481      NaN      NaN     0.075105
# 4          4  linear  1.147698  1.648509      NaN      NaN     0.111954

# %%
print(f"欄位:\n{df_metadata.columns.tolist()}")
# Out:
# 欄位:
# ['sample_id', 'label', 'param_1', 'param_2', 'param_3', 'param_4', 'noise_sigma']

# %%
print(f"資料型態:\n{df_metadata.dtypes}")
# Out:
# 資料型態:
# sample_id        int64
# label              str
# param_1        float64
# param_2        float64
# param_3        float64
# param_4        float64
# noise_sigma    float64
# dtype: object

# %%
print(f"缺失值:\n{df_metadata.isnull().sum()}\n")
# Out:
# 缺失值:
# sample_id         0
# label             0
# param_1           0
# param_2           0
# param_3         500
# param_4        2000
# noise_sigma       0
# dtype: int64

# %%
df_metadata.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sample_id    4000 non-null   int64
#  1   label        4000 non-null   str
#  2   param_1      4000 non-null   float64
#  3   param_2      4000 non-null   float64
#  4   param_3      3500 non-null   float64
#  5   param_4      2000 non-null   float64
#  6   noise_sigma  4000 non-null   float64
# dtypes: float64(5), int64(1), str(1)
# memory usage: 218.9 KB

# %% [markdown]
# ## 清理資料

# %%
df1 = df_dataset.drop(columns=['sample_id'])

# %%
df1 = df1.drop(columns=['noise_sigma'])

# %%
df1.to_csv(r'D:\Python\我的AI作品集\專案1_數學函數辨識\data\v2\function_dataset_cleaned_v2.csv', index=False)

# %%
print(f"清理後dataset資料形狀: {df1.shape}")
# Out:
# 清理後dataset資料形狀: (4000, 11)

# %%
# 進行數據清理
df_metadata.fillna(0, inplace=True)
# Out:
#       sample_id       label   param_1   param_2   param_3  param_4  \
# 0             0      linear  1.095824 -0.611216  0.000000      0.0
# 1             1      linear  1.291046 -0.565858  0.000000      0.0
# 2             2      linear -0.133116 -4.561962  0.000000      0.0
# 3             3      linear  0.679256 -0.628481  0.000000      0.0
# 4             4      linear  1.147698  1.648509  0.000000      0.0
# ...         ...         ...       ...       ...       ...      ...
# 3995       3995  reciprocal  1.160508  3.928990 -0.628689      0.0
# 3996       3996  reciprocal  0.287318  3.771384  1.052570      0.0
# 3997       3997  reciprocal  0.125949  3.125032 -0.438929      0.0
# 3998       3998  reciprocal  1.621294  2.575089 -1.171144      0.0
# 3999       3999  reciprocal -2.997488  3.288252  1.899591      0.0
#
#       noise_sigma
# 0        0.124065
# 1        0.062923
# 2        0.005496
# 3        0.075105
# 4        0.111954
# ...           ...
# 3995     0.003771
# 3996     0.001949
# 3997     0.002175
# 3998     0.026290
# 3999     0.046274
#
# [4000 rows x 7 columns]

# %%
df2 = df_metadata
df2.to_csv(r'D:\Python\我的AI作品集\專案1_數學函數辨識\data\v2\function_metadata_v2.csv', index=False)

# %%
print(f"清理後metadata資料形狀: {df2.shape}")
# Out:
# 清理後metadata資料形狀: (4000, 7)
