# %% [markdown]
# ## 讀取資料

# %%
import pandas as pd

# %%
df_dataset = pd.read_csv(r'D:\Python\我的AI作品集\專案1_數學函數辨識\data\function_dataset.csv')

# %%
print(f"數據外型: {df_dataset.shape}")
# Out:
# 數據外型: (4000, 103)

# %%
print(f"前5筆資料:\n{df_dataset.head()}")
# Out:
# 前5筆資料:
#    sample_id   label     y_000     y_001     y_002     y_003     y_004  \
# 0          0  linear -3.403005 -3.733038 -3.577664 -3.315191 -3.309662
# 1          1  linear -2.857627 -2.771354 -2.653737 -2.742755 -2.570961
# 2          2  linear -2.021211 -1.919763 -1.970171 -1.864069 -1.839360
# 3          3  linear -0.445337 -0.459051 -0.460970 -0.473429 -0.475528
# 4          4  linear  6.563444  6.665102  6.613673  6.178850  6.405070
#
#       y_005     y_006     y_007  ...     y_091     y_092     y_093     y_094  \
# 0 -3.202194 -3.250432 -2.946496  ...  2.280339  2.379688  2.463159  2.574193
# 1 -2.529229 -2.522525 -2.516926  ...  1.957731  2.031790  2.075638  2.155847
# 2 -1.785461 -1.680516 -1.653626  ...  2.353975  2.259261  2.410614  2.405861
# 3 -0.485476 -0.478356 -0.498080  ... -0.881350 -0.879607 -0.889715 -0.893310
# 4  6.001983  5.676718  5.626351  ... -2.683193 -3.256039 -3.596527 -3.463635
#
#       y_095     y_096     y_097     y_098     y_099  noise_sigma
# 0  2.832142  2.719602  2.858312  3.154701  2.994141     0.137103
# 1  2.267429  2.247385  2.330481  2.234488  2.397442     0.055147
# 2  2.464573  2.468551  2.546885  2.665052  2.680951     0.043483
# 3 -0.891343 -0.915625 -0.915402 -0.921323 -0.931880     0.006963
# 4 -4.045978 -3.857056 -3.871363 -4.022210 -3.923957     0.234450
#
# [5 rows x 103 columns]

# %%
print(f"欄位:\n{df_dataset.columns.tolist()}")
# Out:
# 欄位:
# ['sample_id', 'label', 'y_000', 'y_001', 'y_002', 'y_003', 'y_004', 'y_005', 'y_006', 'y_007', 'y_008', 'y_009', 'y_010', 'y_011', 'y_012', 'y_013', 'y_014', 'y_015', 'y_016', 'y_017', 'y_018', 'y_019', 'y_020', 'y_021', 'y_022', 'y_023', 'y_024', 'y_025', 'y_026', 'y_027', 'y_028', 'y_029', 'y_030', 'y_031', 'y_032', 'y_033', 'y_034', 'y_035', 'y_036', 'y_037', 'y_038', 'y_039', 'y_040', 'y_041', 'y_042', 'y_043', 'y_044', 'y_045', 'y_046', 'y_047', 'y_048', 'y_049', 'y_050', 'y_051', 'y_052', 'y_053', 'y_054', 'y_055', 'y_056', 'y_057', 'y_058', 'y_059', 'y_060', 'y_061', 'y_062', 'y_063', 'y_064', 'y_065', 'y_066', 'y_067', 'y_068', 'y_069', 'y_070', 'y_071', 'y_072', 'y_073', 'y_074', 'y_075', 'y_076', 'y_077', 'y_078', 'y_079', 'y_080', 'y_081', 'y_082', 'y_083', 'y_084', 'y_085', 'y_086', 'y_087', 'y_088', 'y_089', 'y_090', 'y_091', 'y_092', 'y_093', 'y_094', 'y_095', 'y_096', 'y_097', 'y_098', 'y_099', 'noise_sigma']

# %%
print(f"資料型態:\n{df_dataset.dtypes}")
# Out:
# 資料型態:
# sample_id        int64
# label              str
# y_000          float64
# y_001          float64
# y_002          float64
#                 ...
# y_096          float64
# y_097          float64
# y_098          float64
# y_099          float64
# noise_sigma    float64
# Length: 103, dtype: object

# %%
print(f"缺失值:\n{df_dataset.isnull().sum()}\n")
# Out:
# 缺失值:
# sample_id      0
# label          0
# y_000          0
# y_001          0
# y_002          0
#               ..
# y_096          0
# y_097          0
# y_098          0
# y_099          0
# noise_sigma    0
# Length: 103, dtype: int64

# %%
print(f"各函數類型數量:\n{df_dataset['label'].value_counts()}\n")       # 查看各類別數量
# Out:
# 各函數類型數量:
# label
# linear         500
# quadratic      500
# cubic          500
# exponential    500
# logarithmic    500
# sine           500
# cosine         500
# reciprocal     500
# Name: count, dtype: int64

# %%
print(f"各函數類型比例:\n{df_dataset['label'].value_counts(normalize=True)}\n") # 查看比例
# Out:
# 各函數類型比例:
# label
# linear         0.125
# quadratic      0.125
# cubic          0.125
# exponential    0.125
# logarithmic    0.125
# sine           0.125
# cosine         0.125
# reciprocal     0.125
# Name: proportion, dtype: float64

# %%
print(f"Noise 統計:\n{df_dataset['noise_sigma'].describe()}")           # 查看noise分布
# Out:
# Noise 統計:
# count    4000.000000
# mean        0.068296
# std         0.058584
# min         0.001000
# 25%         0.025871
# 50%         0.051678
# 75%         0.093287
# max         0.450286
# Name: noise_sigma, dtype: float64

# %%
df_metadata = pd.read_csv(r'D:\Python\我的AI作品集\專案1_數學函數辨識\data\function_metadata.csv')
# 查看基本資料資訊
print(f"數據外型: {df_metadata.shape}")
# Out:
# 數據外型: (4000, 7)

# %%
print(f"前5筆資料:\n{df_metadata.head()}\n")
# Out:
# 前5筆資料:
#    sample_id   label   param_1   param_2  param_3  param_4  noise_sigma
# 0          0  linear  1.643736 -0.244486      NaN      NaN     0.137103
# 1          1  linear  1.301341 -0.202554      NaN      NaN     0.055147
# 2          2  linear  1.165575  0.324466      NaN      NaN     0.043483
# 3          3  linear -0.114537 -0.686555      NaN      NaN     0.006963
# 4          4  linear -2.656608  1.203855      NaN      NaN     0.234450

# %%
print(f"欄位:\n{df_metadata.columns.tolist()}")
# Out:
# 欄位:
# ['sample_id', 'label', 'param_1', 'param_2', 'param_3', 'param_4', 'noise_sigma']

# %%
print(f"資料型態:\n{df_metadata.dtypes}")
# Out:
# 資料型態:
# sample_id        int64
# label              str
# param_1        float64
# param_2        float64
# param_3        float64
# param_4        float64
# noise_sigma    float64
# dtype: object

# %%
print(f"缺失值:\n{df_metadata.isnull().sum()}\n")
# Out:
# 缺失值:
# sample_id         0
# label             0
# param_1           0
# param_2           0
# param_3         500
# param_4        2500
# noise_sigma       0
# dtype: int64

# %%
print(df_metadata.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sample_id    4000 non-null   int64
#  1   label        4000 non-null   str
#  2   param_1      4000 non-null   float64
#  3   param_2      4000 non-null   float64
#  4   param_3      3500 non-null   float64
#  5   param_4      1500 non-null   float64
#  6   noise_sigma  4000 non-null   float64
# dtypes: float64(5), int64(1), str(1)
# memory usage: 218.9 KB
# None

# %% [markdown]
# ## 清理資料

# %%
df1 = df_dataset.drop(columns=['sample_id'])

# %%
df1 = df1.drop(columns=['noise_sigma'])

# %%
df1.to_csv(r'D:\Python\我的AI作品集\專案1_數學函數辨識\data\function_dataset_cleaned.csv', index=False)
print(f"清理後dataset資料形狀: {df1.shape}")
# Out:
# 清理後dataset資料形狀: (4000, 101)

# %%
# 進行數據清理
df_metadata.fillna(0, inplace=True)
# Out:
#       sample_id       label   param_1   param_2   param_3  param_4  \
# 0             0      linear  1.643736 -0.244486  0.000000      0.0
# 1             1      linear  1.301341 -0.202554  0.000000      0.0
# 2             2      linear  1.165575  0.324466  0.000000      0.0
# 3             3      linear -0.114537 -0.686555  0.000000      0.0
# 4             4      linear -2.656608  1.203855  0.000000      0.0
# ...         ...         ...       ...       ...       ...      ...
# 3995       3995  reciprocal  1.728409  2.705279  1.677456      0.0
# 3996       3996  reciprocal -2.842187  2.785224  0.859792      0.0
# 3997       3997  reciprocal  3.532929  3.572261  0.252514      0.0
# 3998       3998  reciprocal  2.785078  3.758994 -1.778660      0.0
# 3999       3999  reciprocal -2.272775  3.909435  0.853173      0.0
#
#       noise_sigma
# 0        0.137103
# 1        0.055147
# 2        0.043483
# 3        0.006963
# 4        0.234450
# ...           ...
# 3995     0.037971
# 3996     0.019247
# 3997     0.031028
# 3998     0.006640
# 3999     0.016503
#
# [4000 rows x 7 columns]

# %%
df2 = df_metadata
df2.to_csv(r'D:\Python\我的AI作品集\專案1_數學函數辨識\data\function_metadata.csv', index=False)
print(f"清理後metadata資料形狀: {df2.shape}")
# Out:
# 清理後metadata資料形狀: (4000, 7)
